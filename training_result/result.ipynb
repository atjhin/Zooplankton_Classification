# %%
from result import *
                                                                                                                                                                                                           
fig = plot_results_table("mnr", save_path="mnr_results.png")

# %%
get_results_table("mnr")
# Out:
#           backbone  expert  macro_accuracy  micro_accuracy  hier_accuracy  \
# 0  efficientnet_b0     cnn          0.9401          0.9451         0.9745
# 1  efficientnet_b0  linear          0.9414          0.9453         0.9752
# 2  efficientnet_b0     mlp          0.9440          0.9481         0.9754
# 3           swin_t     cnn          0.9540          0.9591         0.9822
# 4           swin_t  linear          0.9370          0.9446         0.9756
# 5           swin_t     mlp          0.9509          0.9546         0.9800
#
#    macro_f1  micro_f1  hier_f1
# 0    0.9438    0.9501   0.9689
# 1    0.9433    0.9482   0.9701
# 2    0.9449    0.9508   0.9693
# 3    0.9563    0.9613   0.9775
# 4    0.9401    0.9468   0.9695
# 5    0.9522    0.9570   0.9758

# %%
df = get_results_table("whoi")  # or "mnr"                                                                                                                                                               
df
# Out:
#           backbone  expert  macro_accuracy  micro_accuracy  hier_accuracy  \
# 0  efficientnet_b0     cnn          0.9178          0.9135         0.9556
# 1  efficientnet_b0  linear          0.9144          0.9111         0.9540
# 2  efficientnet_b0     mlp          0.9198          0.9168         0.9578
# 3           swin_t     cnn          0.9290          0.9236         0.9612
# 4           swin_t  linear          0.9279          0.9228         0.9606
# 5           swin_t     mlp          0.9259          0.9221         0.9606
#
#    macro_f1  micro_f1  hier_f1
# 0    0.9084    0.9136   0.9497
# 1    0.9058    0.9112   0.9478
# 2    0.9118    0.9169   0.9521
# 3    0.9193    0.9237   0.9562
# 4    0.9186    0.9229   0.9556
# 5    0.9165    0.9221   0.9552

# %%
from result import plot_confusion_matrix                                                                                                                                     
  
fig = plot_confusion_matrix("mnr/swin_t_cnn", save_path="leaf_confusion_matrx_mnr.png")
